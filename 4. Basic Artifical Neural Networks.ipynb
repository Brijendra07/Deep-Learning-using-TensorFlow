# %% [markdown]
# # Keras syntax basics : Preparing the Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DATA/fake_reg.csv')

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['feature1','feature2']].values

# %%
y = df['price'].values

# %%
X
# Out:
# array([[ 999.78755752,  999.7660962 ],
#        [ 998.86161491, 1001.04240315],
#        [1000.07026691,  998.84401463],
#        ...,
#        [1001.45164617,  998.84760554],
#        [1000.77102275,  998.56285086],
#        [ 999.2322436 , 1001.45140713]])

# %%
y
# Out:
# array([461.52792939, 548.13001146, 410.29716167, 540.38221981,
#        546.02455292, 542.9836716 , 555.48566416, 417.56972453,
#        373.14653122, 633.35029248, 624.24709206, 475.37241721,
#        600.36844486, 532.83295175, 472.8353628 , 506.31229096,
#        508.414406  , 610.4553519 , 323.65776198, 446.21230389,
#        362.12270299, 433.41064026, 562.00257647, 637.30962074,
#        522.80800754, 469.8028243 , 543.10992778, 565.43416994,
#        530.03285381, 610.58016503, 482.55641188, 327.56004052,
#        579.73083872, 448.42981468, 628.97709187, 536.79737216,
#        570.06729543, 357.82557519, 612.08492732, 444.67970846,
#        600.1186364 , 523.53312776, 512.94994495, 614.8813169 ,
#        404.35303251, 643.68851807, 488.95660398, 443.20468572,
#        514.47906638, 514.88174058, 325.05852217, 554.6620585 ,
#        451.39140001, 587.67887726, 477.73749721, 574.51560687,
#        548.9107991 , 528.69088356, 443.21100482, 397.88209319,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (700, 2)

# %%
X_test.shape
# Out:
# (300, 2)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# # Keras Syntax Basics : Creating and Traning the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([Dense(4,activation='relu'),
                   Dense(2,activation='relu'),
                   Dense(1)])

# %%
model = Sequential()  # More preferred method

model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))

model.add(Dense(1))

model.compile(optimizer = 'rmsprop',loss='mse')

# %%
model.fit(x= X_train,y = y_train, epochs = 250)
# Out:
# 2023-05-21 09:32:06.450186: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# 2023-05-21 09:32:06.457172: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# 2023-05-21 09:32:06.457307: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3b4e3c0 executing computations on platform Host. Devices:
# 2023-05-21 09:32:06.457320: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# Train on 700 samples
# Epoch 1/250
# 700/700 [==============================] - 1s 2ms/sample - loss: 256667.1459
# Epoch 2/250
# 700/700 [==============================] - 0s 74us/sample - loss: 256594.0296
# Epoch 3/250
# 700/700 [==============================] - 0s 80us/sample - loss: 256526.9705
# Epoch 4/250
# 700/700 [==============================] - 0s 51us/sample - loss: 256457.4730
# Epoch 5/250
# ...

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df.plot()

# %% [markdown]
# # Keras Syntax Basics : Model Evaluation

# %%
model.evaluate(X_test,y_test,verbose=0)
# Out:
# 144.8281357828776

# %%
model.evaluate(X_train,y_train,verbose=0)
# Out:
# 150.4507338169643

# %%
test_predictions = model.predict(X_test)

# %%
test_predictions
# Out:
# array([[417.95453],
#        [610.71185],
#        [583.57697],
#        [564.0124 ],
#        [381.15897],
#        [571.13934],
#        [512.33057],
#        [466.52225],
#        [543.763  ],
#        [456.49716],
#        [600.396  ],
#        [547.446  ],
#        [429.95157],
#        [420.49994],
#        [637.9285 ],
#        [446.9683 ],
#        [511.25104],
#        [640.5972 ],
#        [644.2276 ],
#        [560.53546],
#        [353.83707],
#        [452.71658],
#        [396.85046],
#        [394.6371 ],
#        [560.2335 ],
#        [597.8943 ],
#        [529.8178 ],
#        [438.13748],
#        [637.32776],
#        [426.75348],
#        [451.95544],
#        [488.47745],
#        [447.40765],
#        [661.01227],
#        [436.87134],
#        [427.78723],
#        [506.12424],
#        [546.39935],
#        [508.16492],
#        [406.67526],
#        [606.92194],
#        [428.739  ],
#        [594.3344 ],
#        [455.74313],
#        [503.30954],
# ...

# %%
test_predictions = pd.Series(test_predictions.reshape(300,))
pred_df = pd.DataFrame(y_test,columns=['Test True Y'])

# %%
pred_df = pd.concat([pred_df,test_predictions],axis=1)

# %%
pred_df.columns = ['Test True Y','Model Predictions']

# %%
pred_df.head()
# Out:
#    Test True Y  Model Predictions
# 0   402.296319         417.954529
# 1   624.156198         610.711853
# 2   582.455066         583.576965
# 3   578.588606         564.012390
# 4   371.224104         381.158966

# %%
sns.scatterplot(x='Test True Y',y= 'Model Predictions',data=pred_df)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(pred_df['Test True Y'],pred_df['Model Predictions'])
# Out:
# 9.597357402907084

# %%
mean_squared_error(pred_df['Test True Y'],pred_df['Model Predictions'])
# Out:
# 144.82814207115

# %%
new_gem = [[998,1000]]

# %%
new_gem = scaler.transform(new_gem)
model.predict(new_gem)
# Out:
# array([[428.2167]], dtype=float32)

# %%
# saving model
from tensorflow.keras.models import load_model

# %%
model.save('my_first_model.h5')

# %%
# error : conda install 'h5py==2.10.0'
later_model = load_model('my_first_model.h5')
# Out:
# WARNING:tensorflow:Sequential models without an `input_shape` passed to the first layer cannot reload their optimizer state. As a result, your model isstarting with a freshly initialized optimizer.

# %%
later_model.predict(new_gem)
# Out:
# array([[428.2167]], dtype=float32)
